# %%
import numpy as np
import os
import cv2
import pandas as pd
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D
from keras.optimizers import RMSprop, Adam, Adadelta
from keras.layers import Input, Embedding, Dense, Dropout, Flatten
from keras.layers import Conv2D,MaxPooling2D,AveragePooling2D
from keras.models import Model
import imutils
# %matplotlib inline
import math
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.models import load_model
import seaborn as sns
import matplotlib.pyplot as pl
from keras import backend as K
K.set_image_dim_ordering('th')
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split,KFold
image_size1 = 85
image_size2 = 128

# %%
#Function to load image data
def load_train(simul=None):
    X_train = []
    y_train = []
    train_ds = pd.read_csv('Train.csv')
    print('Read train images')
    for index, row in train_ds.iterrows():
        image_path = os.path.join('TrainPictures', str(row['Image_Name']) + '.jpg')
        img = cv2.resize(cv2.imread(image_path,cv2.IMREAD_COLOR), (image_size1,image_size2)).astype(np.float32)
        imag1 = img.transpose((2,0,1))
        X_train.append(imag1)
        if simul == 0:
#             print(row['Competency_Score'])
            y_train.append(row['Competency_Score'])
        elif simul == 1:
            y_train.append(row['Trustworthy_Score'])
        else:    
            y_train.append([row['Competency_Score'],row['Trustworthy_Score']])   
        simul = simul     
        #Zoom image
        X_train,y_train = zoom(simul = simul,img = img,X_train = X_train,y_train = y_train,row= row)
        #Rotations
        X_train,y_train = rotation(simul = simul,img = img,X_train = X_train,y_train = y_train, row = row)
    return X_train,y_train

#Read & Normalize data
def read_and_normalize_train_data(simul = None):
    simul = simul 
    train_data, train_target = load_train(simul = simul)
#     print(train_target)
    train_data = np.array(train_data, dtype=np.float32)
    train_target = np.array(train_target, dtype=np.float32)
    train_target = np.array(train_target, dtype=object)
    # normalize inputs from 0-255 to 0-1
    train_data = train_data / 255
    size = len(train_data)
    print('Train shape:', train_data.shape)
    print(train_data.shape[0], 'train samples')
    return train_data, train_target,size

#Zoom image
def zoom(simul,img,X_train,y_train,row):
    zoom_pix = 4
    zoom_factor = 1 + (2*zoom_pix)/image_size2
    image = cv2.resize(img, None, fx=zoom_factor,fy=zoom_factor, interpolation=cv2.INTER_LINEAR)
    top_crop = (image.shape[0] - image_size2)//2
    left_crop = (image.shape[1] - image_size1)//2
    zoomed = image[top_crop: top_crop+image_size2,left_crop: left_crop+image_size1]
    zoomed = np.moveaxis(zoomed, -1, 0)
    X_train.append(zoomed)
    if simul == 0:
        y_train.append(row['Competency_Score'])
    elif simul == 1:
        y_train.append(row['Trustworthy_Score'])
    else:    
         y_train.append([row['Competency_Score'],row['Trustworthy_Score']]) 
    return X_train,y_train

#Rotations
def rotation(simul,img,X_train,y_train,row):
    for angle in np.arange(0, 360, 120):
        (h, w) = img.shape[:2]
        center = (w / 2, h / 2)
        M = cv2.getRotationMatrix2D(center, angle, 1.0)
        rotated = cv2.warpAffine(img, M, (w, h))
        rotated = np.moveaxis(rotated, -1, 0)
        X_train.append(rotated)
        if simul == 0:
            y_train.append(row['Competency_Score'])
        elif simul == 1:
            y_train.append(row['Trustworthy_Score'])
        else:    
            y_train.append([row['Competency_Score'],row['Trustworthy_Score']]) 
    return X_train, y_train

# Creation of model 
def create_model(config,output):
    if config == 1:
        input_layer = Input(shape=(3,image_size2,image_size1))
        x = Conv2D(16, 3, activation='relu')(input_layer)
        x = MaxPooling2D(pool_size=2,data_format="channels_first")(x)
        x = Conv2D(32, 3, activation='relu')(input_layer)
        x = MaxPooling2D(pool_size=2,data_format="channels_first")(x)
        x = Conv2D(64, 3,activation='relu')(x)
        x = MaxPooling2D(pool_size=2,data_format="channels_first")(x) 
        x = Flatten()(x)     
        x = Dense(500, activation='relu')(x)
        x = Dropout(0.5)(x)
        x = Dense(100, activation='relu')(x)
        x = Dropout(0.25)(x)
        x = Dense(20, activation='relu')(x)
        if output == 1:
            output_layer = Dense(1, activation='relu')(x)
        elif output == 2:
            output_layer = Dense(2, activation='relu')(x)
        model = Model(input_layer, output_layer)
        model.compile(loss='mean_squared_error', optimizer=Adam(), metrics=['mae','acc'])
        return model
    elif config == 2: 
        input_layer = Input(shape=(3,image_size2,image_size1))
        x = Conv2D(32, 3, activation='relu')(input_layer)
        x = MaxPooling2D(pool_size=2,data_format="channels_first")(x)
        x = Flatten()(x)     
        x = Dense(256, activation='relu')(x)
        x = Dropout(0.2)(x)
        x = Dense(64, activation='relu')(x)
        x = Dropout(0.2)(x)
        x = Dense(128, activation='relu')(x)
        x = Dropout(0.2)(x)
        if output == 1:
            output_layer = Dense(1, activation='relu')(x)
        elif output == 2:
            output_layer = Dense(2, activation='relu')(x)
        model = Model(input_layer, output_layer)
        model.compile(loss='mean_squared_error', optimizer=Adam(), metrics=['mae','acc'])
        return model
    elif config == 3:
        input_layer = Input(shape=(3,image_size2,image_size1))
        x = Conv2D(32, 3, activation='relu')(input_layer)
        x = MaxPooling2D(pool_size=2,data_format="channels_first")(x)       
#         x = BatchNormalization(axis= 3)  
        x = Conv2D(64, 3, activation='relu')(x)
        x = MaxPooling2D(pool_size=2,data_format="channels_first")(x)        
#         x = BatchNormalization(axis= 3)    
        x = Conv2D(128, 3, activation='relu')(x)
        x = MaxPooling2D(pool_size=2,data_format="channels_first")(x)        
#         x = BatchNormalization(axis = 3)(x)
        x = Conv2D(64, 3, activation='relu')(x)
        x = GlobalAveragePooling2D()(x)
        if output == 1:
            output_layer = Dense(1, activation='relu')(x)
        elif output == 2:
            output_layer = Dense(2, activation='relu')(x)
        model = Model(input_layer, output_layer)
        model.compile(loss='mean_squared_error', optimizer=Adam(), metrics=['mae'])
    
#Training Model    
def train_model(batch_size = 50, nb_epoch = 5,simul = None,Output = 2,config = 1):     
    train_data, train_target,size = read_and_normalize_train_data(simul = simul)
    kfold = KFold(n_splits=5, shuffle=True, random_state=1)
    model = create_model(config = 1, output = Output)
    for j, (train_idx, val_idx) in enumerate(kfold.split(train_data, train_target)):
        print('\nFold ',j)
        X_train_cv = train_data[train_idx]
        y_train_cv = train_target[train_idx]
        X_valid_cv = train_data[val_idx]
        y_valid_cv = train_target[val_idx] 
        name_weights = "final_model_fold" + str(j) + "_weights.h5"
        model.compile(loss='mean_squared_error', optimizer=Adam(), metrics=['mae'])
        checkpoint = ModelCheckpoint(name_weights,monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
        earlystopping = EarlyStopping(monitor='val_loss',patience=5, verbose=1, mode='auto', restore_best_weights=True)
        callbacks_list = [checkpoint,earlystopping]
        model.fit(X_train_cv, y_train_cv, batch_size=batch_size,epochs=nb_epoch,callbacks=callbacks_list,verbose=1, validation_data=(X_valid_cv, y_valid_cv))
        score = model.evaluate(X_valid_cv, y_valid_cv)
        print(model.metrics_names)
        print('Test score:', score)        
    return model

# %% [markdown]
# # Simultaneous Regression

# %%
model = train_model(batch_size = 50, nb_epoch = 5,simul = None,Output = 2,config = 2)
# Out:
# Read train images
# Train shape: (4000, 3, 128, 85)
# 4000 train samples
#
# Fold  0
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 211s 66ms/step - loss: 8.1521 - mean_absolute_error: 2.2143 - val_loss: 4.4295 - val_mean_absolute_error: 1.7142
#
# Epoch 00001: val_loss improved from inf to 4.42955, saving model to final_model_fold0_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 205s 64ms/step - loss: 4.9955 - mean_absolute_error: 1.8042 - val_loss: 3.9755 - val_mean_absolute_error: 1.6263
#
# Epoch 00002: val_loss improved from 4.42955 to 3.97548, saving model to final_model_fold0_weights.h5
# Epoch 3/5
# 3200/3200 [==============================] - 206s 64ms/step - loss: 4.5660 - mean_absolute_error: 1.7258 - val_loss: 3.2816 - val_mean_absolute_error: 1.4604
#
# Epoch 00003: val_loss improved from 3.97548 to 3.28158, saving model to final_model_fold0_weights.h5
# Epoch 4/5
# 3200/3200 [==============================] - 206s 64ms/step - loss: 4.2528 - mean_absolute_error: 1.6559 - val_loss: 3.3828 - val_mean_absolute_error: 1.4894
#
# Epoch 00004: val_loss did not improve from 3.28158
# Epoch 5/5
# 3200/3200 [==============================] - 204s 64ms/step - loss: 3.9314 - mean_absolute_error: 1.6039 - val_loss: 3.1333 - val_mean_absolute_error: 1.4199
#
# Epoch 00005: val_loss improved from 3.28158 to 3.13329, saving model to final_model_fold0_weights.h5
# 800/800 [==============================] - 25s 31ms/step
# ['loss', 'mean_absolute_error']
# Test score: [3.133289270401001, 1.419873833656311]
#
# Fold  1
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 207s 65ms/step - loss: 4.0683 - mean_absolute_error: 1.6184 - val_loss: 2.9002 - val_mean_absolute_error: 1.3722
#
# Epoch 00001: val_loss improved from inf to 2.90022, saving model to final_model_fold1_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 209s 65ms/step - loss: 3.4956 - mean_absolute_error: 1.4939 - val_loss: 3.5158 - val_mean_absolute_error: 1.5422
#
# Epoch 00002: val_loss did not improve from 2.90022
# Epoch 3/5
# 3200/3200 [==============================] - 209s 65ms/step - loss: 3.2368 - mean_absolute_error: 1.4379 - val_loss: 3.2583 - val_mean_absolute_error: 1.4731
#
# Epoch 00003: val_loss did not improve from 2.90022
# Epoch 4/5
# 3200/3200 [==============================] - 208s 65ms/step - loss: 2.9328 - mean_absolute_error: 1.3670 - val_loss: 2.6506 - val_mean_absolute_error: 1.2900
#
# Epoch 00004: val_loss improved from 2.90022 to 2.65056, saving model to final_model_fold1_weights.h5
# Epoch 5/5
# 3200/3200 [==============================] - 204s 64ms/step - loss: 2.8074 - mean_absolute_error: 1.3295 - val_loss: 2.6621 - val_mean_absolute_error: 1.2861
#
# Epoch 00005: val_loss did not improve from 2.65056
# 800/800 [==============================] - 23s 29ms/step
# ['loss', 'mean_absolute_error']
# Test score: [2.6620935678482054, 1.2860593128204345]
#
# Fold  2
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 212s 66ms/step - loss: 3.0809 - mean_absolute_error: 1.4013 - val_loss: 2.3429 - val_mean_absolute_error: 1.2171
#
# Epoch 00001: val_loss improved from inf to 2.34294, saving model to final_model_fold2_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 209s 65ms/step - loss: 2.4703 - mean_absolute_error: 1.2488 - val_loss: 1.9304 - val_mean_absolute_error: 1.0945
#
# Epoch 00002: val_loss improved from 2.34294 to 1.93039, saving model to final_model_fold2_weights.h5
# Epoch 3/5
# 3200/3200 [==============================] - 216s 68ms/step - loss: 2.3872 - mean_absolute_error: 1.2198 - val_loss: 1.9221 - val_mean_absolute_error: 1.0819
#
# Epoch 00003: val_loss improved from 1.93039 to 1.92212, saving model to final_model_fold2_weights.h5
# Epoch 4/5
# 3200/3200 [==============================] - 215s 67ms/step - loss: 2.2390 - mean_absolute_error: 1.1904 - val_loss: 1.9659 - val_mean_absolute_error: 1.0998
#
# Epoch 00004: val_loss did not improve from 1.92212
# Epoch 5/5
# 3200/3200 [==============================] - 212s 66ms/step - loss: 2.0662 - mean_absolute_error: 1.1296 - val_loss: 2.2303 - val_mean_absolute_error: 1.1931
#
# Epoch 00005: val_loss did not improve from 1.92212
# 800/800 [==============================] - 26s 32ms/step
# ['loss', 'mean_absolute_error']
# Test score: [2.2303178405761717, 1.193114845752716]
#
# Fold  3
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 211s 66ms/step - loss: 2.3061 - mean_absolute_error: 1.2072 - val_loss: 1.5862 - val_mean_absolute_error: 0.9822
#
# Epoch 00001: val_loss improved from inf to 1.58620, saving model to final_model_fold3_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 213s 67ms/step - loss: 2.0613 - mean_absolute_error: 1.1294 - val_loss: 1.4454 - val_mean_absolute_error: 0.9396
#
# Epoch 00002: val_loss improved from 1.58620 to 1.44545, saving model to final_model_fold3_weights.h5
# Epoch 3/5
# 3200/3200 [==============================] - 209s 65ms/step - loss: 1.8692 - mean_absolute_error: 1.0832 - val_loss: 1.4896 - val_mean_absolute_error: 0.9416
#
# Epoch 00003: val_loss did not improve from 1.44545
# Epoch 4/5
# 3200/3200 [==============================] - 225s 70ms/step - loss: 1.8559 - mean_absolute_error: 1.0727 - val_loss: 2.1532 - val_mean_absolute_error: 1.1890
#
# Epoch 00004: val_loss did not improve from 1.44545
# Epoch 5/5
# 3200/3200 [==============================] - 212s 66ms/step - loss: 1.8511 - mean_absolute_error: 1.0725 - val_loss: 1.4834 - val_mean_absolute_error: 0.9421
#
# Epoch 00005: val_loss did not improve from 1.44545
# 800/800 [==============================] - 24s 30ms/step
# ['loss', 'mean_absolute_error']
# Test score: [1.4833708429336547, 0.9421054244041442]
#
# Fold  4
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 211s 66ms/step - loss: 1.9061 - mean_absolute_error: 1.0876 - val_loss: 1.3199 - val_mean_absolute_error: 0.9038
#
# Epoch 00001: val_loss improved from inf to 1.31986, saving model to final_model_fold4_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 210s 66ms/step - loss: 1.7895 - mean_absolute_error: 1.0532 - val_loss: 1.5262 - val_mean_absolute_error: 0.9811
#
# Epoch 00002: val_loss did not improve from 1.31986
# Epoch 3/5
# 3200/3200 [==============================] - 204s 64ms/step - loss: 1.7100 - mean_absolute_error: 1.0256 - val_loss: 1.3989 - val_mean_absolute_error: 0.9385
#
# Epoch 00003: val_loss did not improve from 1.31986
# Epoch 4/5
# 3200/3200 [==============================] - 207s 65ms/step - loss: 1.6682 - mean_absolute_error: 1.0203 - val_loss: 1.3609 - val_mean_absolute_error: 0.9199
#
# Epoch 00004: val_loss did not improve from 1.31986
# Epoch 5/5
# 3200/3200 [==============================] - 220s 69ms/step - loss: 1.6162 - mean_absolute_error: 1.0035 - val_loss: 1.3917 - val_mean_absolute_error: 0.9244
#
# Epoch 00005: val_loss did not improve from 1.31986
# 800/800 [==============================] - 27s 33ms/step
# ['loss', 'mean_absolute_error']
# Test score: [1.3916953897476196, 0.9243886709213257]

# %%
test_ds = pd.read_csv('Test_p.csv')
#Predictions
x =[]
y=[]
for index, row in test_ds.iterrows():
        image_path = os.path.join('TrainPictures', str(row['Image_Name']) + '.jpg')
        img = cv2.resize(cv2.imread(image_path,cv2.IMREAD_COLOR), (image_size1,image_size2)).astype(np.float32)
        img = img.reshape( (1,3,128, 85) )
        img = img / 255
        a  = model.predict(img)
        x.append(str(row['Image_Name']) + '.jpg')
        y.append(a) 
# Test Results
a = np.array(y)
a = a.reshape(-1,2)
df_results = pd.DataFrame()
df_results['Image_Name'] = x
df_results['Combined Test Score'] = y
df_results[['Competency_Score_P','Trustworthy_Score_P']] = pd.DataFrame(a)
df_results['Competency_Score_P'] = round(df_results['Competency_Score_P'], 2)
df_results['Trustworthy_Score_P'] = round(df_results['Trustworthy_Score_P'], 2)
df_results['Competency_Score_A'] = test_ds['Competency_Score']
df_results['Trustworthy_Score_A'] = test_ds['Trustworthy_Score']
df_results = df_results[['Image_Name', 'Competency_Score_P', 'Trustworthy_Score_P','Competency_Score_A','Trustworthy_Score_A']]
print(df_results.head(5))
mae_comp = np.sum(np.absolute(df_results['Competency_Score_P'] - df_results['Competency_Score_A']))/len(df_results)
mae_trust = np.sum(np.absolute(df_results['Trustworthy_Score_P'] - df_results['Trustworthy_Score_A']))/len(df_results)
print("MAE Competency:", mae_comp)
print("MAE Trustworthy:", mae_trust)
print("MAE Combined:", mae_trust+mae_comp)
# Out:
#   Image_Name  Competency_Score_P  Trustworthy_Score_P  Competency_Score_A  \
# 0   B268.jpg                2.44                 2.38                3.00
# 1   B287.jpg                3.54                 3.42                8.00
# 2   B467.jpg                2.11                 2.08                7.67
# 3   B506.jpg                2.37                 2.32                5.88
# 4   B292.jpg                2.64                 2.57                9.00
#
#    Trustworthy_Score_A
# 0                 5.00
# 1                 2.50
# 2                 6.67
# 3                 5.62
# 4                 9.00
# MAE Competency: 3.6812686631928626
# MAE Trustworthy: 3.5289552259801034
# MAE Combined: 7.2102238891729655

# %%
sns.pairplot(df_results)

# %% [markdown]
# # Individual Regression - Only on Competency Score

# %%
model = train_model(batch_size = 50, nb_epoch = 5,simul = 0,Output = 1,config = 2)
# Out:
# Read train images
# Train shape: (4000, 3, 128, 85)
# 4000 train samples
#
# Fold  0
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 207s 65ms/step - loss: 6.5984 - mean_absolute_error: 2.0488 - val_loss: 4.7533 - val_mean_absolute_error: 1.7934
#
# Epoch 00001: val_loss improved from inf to 4.75334, saving model to final_model_fold0_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 217s 68ms/step - loss: 4.7164 - mean_absolute_error: 1.7522 - val_loss: 3.2845 - val_mean_absolute_error: 1.4604
#
# Epoch 00002: val_loss improved from 4.75334 to 3.28445, saving model to final_model_fold0_weights.h5
# Epoch 3/5
# 3200/3200 [==============================] - 205s 64ms/step - loss: 4.3395 - mean_absolute_error: 1.6675 - val_loss: 3.0444 - val_mean_absolute_error: 1.4015
#
# Epoch 00003: val_loss improved from 3.28445 to 3.04438, saving model to final_model_fold0_weights.h5
# Epoch 4/5
# 3200/3200 [==============================] - 243s 76ms/step - loss: 4.1499 - mean_absolute_error: 1.6274 - val_loss: 4.4732 - val_mean_absolute_error: 1.7501
#
# Epoch 00004: val_loss did not improve from 3.04438
# Epoch 5/5
# 3200/3200 [==============================] - 224s 70ms/step - loss: 3.6166 - mean_absolute_error: 1.5282 - val_loss: 3.6389 - val_mean_absolute_error: 1.5489
#
# Epoch 00005: val_loss did not improve from 3.04438
# 800/800 [==============================] - 26s 32ms/step
# ['loss', 'mean_absolute_error']
# Test score: [3.638928928375244, 1.548906602859497]
#
# Fold  1
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 210s 66ms/step - loss: 3.7690 - mean_absolute_error: 1.5477 - val_loss: 3.2961 - val_mean_absolute_error: 1.4876
#
# Epoch 00001: val_loss improved from inf to 3.29612, saving model to final_model_fold1_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 233s 73ms/step - loss: 2.9249 - mean_absolute_error: 1.3630 - val_loss: 3.1337 - val_mean_absolute_error: 1.4443
#
# Epoch 00002: val_loss improved from 3.29612 to 3.13371, saving model to final_model_fold1_weights.h5
# Epoch 3/5
# 3200/3200 [==============================] - 232s 73ms/step - loss: 2.4385 - mean_absolute_error: 1.2296 - val_loss: 2.3548 - val_mean_absolute_error: 1.2033
#
# Epoch 00003: val_loss improved from 3.13371 to 2.35484, saving model to final_model_fold1_weights.h5
# Epoch 4/5
# 3200/3200 [==============================] - 214s 67ms/step - loss: 2.1095 - mean_absolute_error: 1.1460 - val_loss: 2.1801 - val_mean_absolute_error: 1.1440
#
# Epoch 00004: val_loss improved from 2.35484 to 2.18011, saving model to final_model_fold1_weights.h5
# Epoch 5/5
# 3200/3200 [==============================] - 216s 67ms/step - loss: 1.9261 - mean_absolute_error: 1.0831 - val_loss: 2.7076 - val_mean_absolute_error: 1.2888
#
# Epoch 00005: val_loss did not improve from 2.18011
# 800/800 [==============================] - 23s 29ms/step
# ['loss', 'mean_absolute_error']
# Test score: [2.707596983909607, 1.2888133549690246]
#
# Fold  2
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 226s 71ms/step - loss: 2.6313 - mean_absolute_error: 1.2627 - val_loss: 1.2882 - val_mean_absolute_error: 0.8924
#
# Epoch 00001: val_loss improved from inf to 1.28819, saving model to final_model_fold2_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 228s 71ms/step - loss: 1.7644 - mean_absolute_error: 1.0411 - val_loss: 1.1100 - val_mean_absolute_error: 0.8276
#
# Epoch 00002: val_loss improved from 1.28819 to 1.11003, saving model to final_model_fold2_weights.h5
# Epoch 3/5
# 3200/3200 [==============================] - 226s 71ms/step - loss: 1.5408 - mean_absolute_error: 0.9647 - val_loss: 1.4879 - val_mean_absolute_error: 0.9912
#
# Epoch 00003: val_loss did not improve from 1.11003
# Epoch 4/5
# 3200/3200 [==============================] - 205s 64ms/step - loss: 1.3201 - mean_absolute_error: 0.8878 - val_loss: 1.2036 - val_mean_absolute_error: 0.8589
#
# Epoch 00004: val_loss did not improve from 1.11003
# Epoch 5/5
# 3200/3200 [==============================] - 210s 66ms/step - loss: 1.1834 - mean_absolute_error: 0.8614 - val_loss: 1.0916 - val_mean_absolute_error: 0.7981
#
# Epoch 00005: val_loss improved from 1.11003 to 1.09156, saving model to final_model_fold2_weights.h5
# 800/800 [==============================] - 30s 38ms/step
# ['loss', 'mean_absolute_error']
# Test score: [1.0915619492530824, 0.7980732178688049]
#
# Fold  3
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 219s 69ms/step - loss: 1.4983 - mean_absolute_error: 0.9511 - val_loss: 0.9795 - val_mean_absolute_error: 0.8120
#
# Epoch 00001: val_loss improved from inf to 0.97946, saving model to final_model_fold3_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 248s 77ms/step - loss: 1.2365 - mean_absolute_error: 0.8709 - val_loss: 0.5857 - val_mean_absolute_error: 0.5904
#
# Epoch 00002: val_loss improved from 0.97946 to 0.58573, saving model to final_model_fold3_weights.h5
# Epoch 3/5
# 3200/3200 [==============================] - 224s 70ms/step - loss: 1.0636 - mean_absolute_error: 0.8035 - val_loss: 0.6929 - val_mean_absolute_error: 0.6343
#
# Epoch 00003: val_loss did not improve from 0.58573
# Epoch 4/5
# 3200/3200 [==============================] - 207s 65ms/step - loss: 0.9306 - mean_absolute_error: 0.7542 - val_loss: 1.8120 - val_mean_absolute_error: 1.1397
#
# Epoch 00004: val_loss did not improve from 0.58573
# Epoch 5/5
# 3200/3200 [==============================] - 212s 66ms/step - loss: 0.9120 - mean_absolute_error: 0.7490 - val_loss: 0.7172 - val_mean_absolute_error: 0.6429
#
# Epoch 00005: val_loss did not improve from 0.58573
# 800/800 [==============================] - 23s 29ms/step
# ['loss', 'mean_absolute_error']
# Test score: [0.7172258412837982, 0.6428949093818664]
#
# Fold  4
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 207s 65ms/step - loss: 1.0801 - mean_absolute_error: 0.8102 - val_loss: 0.4722 - val_mean_absolute_error: 0.5375
#
# Epoch 00001: val_loss improved from inf to 0.47224, saving model to final_model_fold4_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 215s 67ms/step - loss: 0.8939 - mean_absolute_error: 0.7422 - val_loss: 0.5753 - val_mean_absolute_error: 0.5970
#
# Epoch 00002: val_loss did not improve from 0.47224
# Epoch 3/5
# 3200/3200 [==============================] - 204s 64ms/step - loss: 0.8956 - mean_absolute_error: 0.7441 - val_loss: 0.6340 - val_mean_absolute_error: 0.6351
#
# Epoch 00003: val_loss did not improve from 0.47224
# Epoch 4/5
# 3200/3200 [==============================] - 204s 64ms/step - loss: 0.7884 - mean_absolute_error: 0.6956 - val_loss: 0.7182 - val_mean_absolute_error: 0.6682
#
# Epoch 00004: val_loss did not improve from 0.47224
# Epoch 5/5
# 3200/3200 [==============================] - 203s 63ms/step - loss: 0.7210 - mean_absolute_error: 0.6620 - val_loss: 0.7501 - val_mean_absolute_error: 0.6838
#
# Epoch 00005: val_loss did not improve from 0.47224
# 800/800 [==============================] - 23s 29ms/step
# ['loss', 'mean_absolute_error']
# Test score: [0.7501209270954132, 0.6837983536720276]

# %%
test_ds = pd.read_csv('Test_p.csv')
#Predictions
x =[]
y=[]
for index, row in test_ds.iterrows():
        image_path = os.path.join('TrainPictures', str(row['Image_Name']) + '.jpg')
        img = cv2.resize(cv2.imread(image_path,cv2.IMREAD_COLOR), (image_size1,image_size2)).astype(np.float32)
        img = img.reshape( (1,3,128, 85) )
        img = img / 255
        a  = model.predict(img)
        x.append(str(row['Image_Name']) + '.jpg')
        y.append(a)
        # Test Results
a = np.array(y)
a = a.reshape(-1,1)
df_results = pd.DataFrame()
df_results['Image_Name'] = x
df_results[['Competency_Score_P']] = pd.DataFrame(a)
df_results['Competency_Score_P'] = round(df_results['Competency_Score_P'], 2)
df_results['Competency_Score_A'] = test_ds['Competency_Score']
df_results = df_results[['Image_Name', 'Competency_Score_P','Competency_Score_A']]
print(df_results.head(5))
mae_comp = np.sum(np.absolute(df_results['Competency_Score_P'] - df_results['Competency_Score_A']))/len(df_results)
print("MAE Competency:", mae_comp)
sns.pairplot(df_results)
# Out:
#   Image_Name  Competency_Score_P  Competency_Score_A
# 0   B268.jpg                3.58                3.00
# 1   B287.jpg                4.70                8.00
# 2   B467.jpg                3.53                7.67
# 3   B506.jpg                3.33                5.88
# 4   B292.jpg                2.85                9.00
# MAE Competency: 2.6980597143742577

# %% [markdown]
# # Individual Regression - Only on Trustworthy Score

# %%
model = train_model(batch_size = 50, nb_epoch = 5,simul = 1,Output = 1,config = 2)
# Out:
# Read train images
# Train shape: (4000, 3, 128, 85)
# 4000 train samples
#
# Fold  0
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 209s 65ms/step - loss: 7.7864 - mean_absolute_error: 2.1969 - val_loss: 6.9634 - val_mean_absolute_error: 2.2339
#
# Epoch 00001: val_loss improved from inf to 6.96344, saving model to final_model_fold0_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 210s 66ms/step - loss: 5.0685 - mean_absolute_error: 1.8250 - val_loss: 4.5514 - val_mean_absolute_error: 1.7540
#
# Epoch 00002: val_loss improved from 6.96344 to 4.55144, saving model to final_model_fold0_weights.h5
# Epoch 3/5
# 3200/3200 [==============================] - 211s 66ms/step - loss: 4.6934 - mean_absolute_error: 1.7458 - val_loss: 4.7882 - val_mean_absolute_error: 1.8111
#
# Epoch 00003: val_loss did not improve from 4.55144
# Epoch 4/5
# 3200/3200 [==============================] - 202s 63ms/step - loss: 4.2410 - mean_absolute_error: 1.6672 - val_loss: 3.6339 - val_mean_absolute_error: 1.5487
#
# Epoch 00004: val_loss improved from 4.55144 to 3.63388, saving model to final_model_fold0_weights.h5
# Epoch 5/5
# 3200/3200 [==============================] - 210s 66ms/step - loss: 3.9767 - mean_absolute_error: 1.6052 - val_loss: 3.2046 - val_mean_absolute_error: 1.4466
#
# Epoch 00005: val_loss improved from 3.63388 to 3.20463, saving model to final_model_fold0_weights.h5
# 800/800 [==============================] - 29s 36ms/step
# ['loss', 'mean_absolute_error']
# Test score: [3.2046294021606445, 1.4466262316703797]
#
# Fold  1
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 208s 65ms/step - loss: 4.3137 - mean_absolute_error: 1.6742 - val_loss: 4.1138 - val_mean_absolute_error: 1.6958
#
# Epoch 00001: val_loss improved from inf to 4.11377, saving model to final_model_fold1_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 212s 66ms/step - loss: 3.6522 - mean_absolute_error: 1.5292 - val_loss: 2.9655 - val_mean_absolute_error: 1.4172
#
# Epoch 00002: val_loss improved from 4.11377 to 2.96553, saving model to final_model_fold1_weights.h5
# Epoch 3/5
# 3200/3200 [==============================] - 210s 66ms/step - loss: 3.1502 - mean_absolute_error: 1.4159 - val_loss: 2.9510 - val_mean_absolute_error: 1.4081
#
# Epoch 00003: val_loss improved from 2.96553 to 2.95101, saving model to final_model_fold1_weights.h5
# Epoch 4/5
# 3200/3200 [==============================] - 209s 65ms/step - loss: 3.0051 - mean_absolute_error: 1.3873 - val_loss: 3.4586 - val_mean_absolute_error: 1.5502
#
# Epoch 00004: val_loss did not improve from 2.95101
# Epoch 5/5
# 3200/3200 [==============================] - 218s 68ms/step - loss: 2.5383 - mean_absolute_error: 1.2583 - val_loss: 3.0202 - val_mean_absolute_error: 1.4216
#
# Epoch 00005: val_loss did not improve from 2.95101
# 800/800 [==============================] - 23s 28ms/step
# ['loss', 'mean_absolute_error']
# Test score: [3.0202171754837037, 1.4216422748565674]
#
# Fold  2
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 205s 64ms/step - loss: 2.6552 - mean_absolute_error: 1.2878 - val_loss: 3.2326 - val_mean_absolute_error: 1.5108
#
# Epoch 00001: val_loss improved from inf to 3.23262, saving model to final_model_fold2_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 216s 68ms/step - loss: 2.1526 - mean_absolute_error: 1.1529 - val_loss: 2.0913 - val_mean_absolute_error: 1.1640
#
# Epoch 00002: val_loss improved from 3.23262 to 2.09130, saving model to final_model_fold2_weights.h5
# Epoch 3/5
# 3200/3200 [==============================] - 211s 66ms/step - loss: 1.9403 - mean_absolute_error: 1.0937 - val_loss: 1.8940 - val_mean_absolute_error: 1.1037
#
# Epoch 00003: val_loss improved from 2.09130 to 1.89398, saving model to final_model_fold2_weights.h5
# Epoch 4/5
# 3200/3200 [==============================] - 208s 65ms/step - loss: 1.6148 - mean_absolute_error: 1.0021 - val_loss: 1.7281 - val_mean_absolute_error: 1.0338
#
# Epoch 00004: val_loss improved from 1.89398 to 1.72814, saving model to final_model_fold2_weights.h5
# Epoch 5/5
# 3200/3200 [==============================] - 208s 65ms/step - loss: 1.4458 - mean_absolute_error: 0.9340 - val_loss: 2.1945 - val_mean_absolute_error: 1.2147
#
# Epoch 00005: val_loss did not improve from 1.72814
# 800/800 [==============================] - 23s 29ms/step
# ['loss', 'mean_absolute_error']
# Test score: [2.1945334005355837, 1.214684841632843]
#
# Fold  3
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 207s 65ms/step - loss: 1.6987 - mean_absolute_error: 1.0117 - val_loss: 1.2861 - val_mean_absolute_error: 0.9252
#
# Epoch 00001: val_loss improved from inf to 1.28610, saving model to final_model_fold3_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 243s 76ms/step - loss: 1.3980 - mean_absolute_error: 0.9171 - val_loss: 1.0971 - val_mean_absolute_error: 0.7987
#
# Epoch 00002: val_loss improved from 1.28610 to 1.09712, saving model to final_model_fold3_weights.h5
# Epoch 3/5
# 3200/3200 [==============================] - 275s 86ms/step - loss: 1.1846 - mean_absolute_error: 0.8552 - val_loss: 1.0888 - val_mean_absolute_error: 0.8102
#
# Epoch 00003: val_loss improved from 1.09712 to 1.08883, saving model to final_model_fold3_weights.h5
# Epoch 4/5
# 3200/3200 [==============================] - 267s 83ms/step - loss: 1.1300 - mean_absolute_error: 0.8341 - val_loss: 1.2351 - val_mean_absolute_error: 0.8767
#
# Epoch 00004: val_loss did not improve from 1.08883
# Epoch 5/5
# 3200/3200 [==============================] - 263s 82ms/step - loss: 1.0346 - mean_absolute_error: 0.7989 - val_loss: 1.0579 - val_mean_absolute_error: 0.7949
#
# Epoch 00005: val_loss improved from 1.08883 to 1.05788, saving model to final_model_fold3_weights.h5
# 800/800 [==============================] - 34s 42ms/step
# ['loss', 'mean_absolute_error']
# Test score: [1.0578847050666809, 0.7949151086807251]
#
# Fold  4
# Train on 3200 samples, validate on 800 samples
# Epoch 1/5
# 3200/3200 [==============================] - 278s 87ms/step - loss: 1.2047 - mean_absolute_error: 0.8506 - val_loss: 0.5304 - val_mean_absolute_error: 0.5580
#
# Epoch 00001: val_loss improved from inf to 0.53036, saving model to final_model_fold4_weights.h5
# Epoch 2/5
# 3200/3200 [==============================] - 275s 86ms/step - loss: 1.0700 - mean_absolute_error: 0.8132 - val_loss: 0.5399 - val_mean_absolute_error: 0.5461
#
# Epoch 00002: val_loss did not improve from 0.53036
# Epoch 3/5
# 3200/3200 [==============================] - 218s 68ms/step - loss: 0.9605 - mean_absolute_error: 0.7701 - val_loss: 0.5959 - val_mean_absolute_error: 0.6009
#
# Epoch 00003: val_loss did not improve from 0.53036
# Epoch 4/5
# 3200/3200 [==============================] - 209s 65ms/step - loss: 0.8507 - mean_absolute_error: 0.7242 - val_loss: 0.6576 - val_mean_absolute_error: 0.6545
#
# Epoch 00004: val_loss did not improve from 0.53036
# Epoch 5/5
# 3200/3200 [==============================] - 210s 66ms/step - loss: 0.7889 - mean_absolute_error: 0.6908 - val_loss: 0.8737 - val_mean_absolute_error: 0.7455
#
# Epoch 00005: val_loss did not improve from 0.53036
# 800/800 [==============================] - 24s 29ms/step
# ['loss', 'mean_absolute_error']
# Test score: [0.873695342540741, 0.7455446863174439]

# %%
test_ds = pd.read_csv('Test_p.csv')
#Predictions
x =[]
y=[]
for index, row in test_ds.iterrows():
        image_path = os.path.join('TrainPictures', str(row['Image_Name']) + '.jpg')
        img = cv2.resize(cv2.imread(image_path,cv2.IMREAD_COLOR), (image_size1,image_size2)).astype(np.float32)
        img = img.reshape( (1,3,128, 85) )
        img = img / 255
        a  = model.predict(img)
        x.append(str(row['Image_Name']) + '.jpg')
        y.append(a)
        # Test Results
a = np.array(y)
a = a.reshape(-1,1)
df_results['Image_Name'] = x
df_results[['Trustworthy_Score_P']] = pd.DataFrame(a)
df_results['Trustworthy_Score_P'] = round(df_results['Trustworthy_Score_P'], 2)
df_results['Trustworthy_Score_A'] = test_ds['Trustworthy_Score']
df_results = df_results[['Image_Name','Trustworthy_Score_P','Trustworthy_Score_A']]
print(df_results.head(5))
mae_trust = np.sum(np.absolute(df_results['Trustworthy_Score_P'] - df_results['Trustworthy_Score_A']))/len(df_results)
print("MAE Trustworthy:", mae_trust)
sns.pairplot(df_results)
# Out:
#   Image_Name  Trustworthy_Score_P  Trustworthy_Score_A
# 0   B268.jpg                 2.62                 5.00
# 1   B287.jpg                 3.98                 2.50
# 2   B467.jpg                 2.78                 6.67
# 3   B506.jpg                 3.03                 5.62
# 4   B292.jpg                 2.70                 9.00
# MAE Trustworthy: 3.0930597091788674

# %% [markdown]
# # Final Test

# %%
model = create_model(config = 1, output = 2)
filepath="final_model_fold0_weights.h5"
model.load_weights(filepath)
test_ds = pd.read_csv('Test_p.csv')
#Predictions
x =[]
y=[]
for index, row in test_ds.iterrows():
        image_path = os.path.join('TrainPictures', str(row['Image_Name']) + '.jpg')
        img = cv2.resize(cv2.imread(image_path,cv2.IMREAD_COLOR), (image_size1,image_size2)).astype(np.float32)
        img = img.reshape( (1,3,128, 85) )
        img = img / 255
        a  = model.predict(img)
        x.append(str(row['Image_Name']) + '.jpg')
        y.append(a)

# %%
# Test Results
a = np.array(y)
a = a.reshape(-1,2)
df_results = pd.DataFrame()
df_results['Image_Name'] = x
df_results['Combined Test Score'] = y
df_results[['Competency_Score_P','Trustworthy_Score_P']] = pd.DataFrame(a)
df_results['Competency_Score_P'] = round(df_results['Competency_Score_P'], 2)
df_results['Trustworthy_Score_P'] = round(df_results['Trustworthy_Score_P'], 2)
df_results['Competency_Score_A'] = test_ds['Competency_Score']
df_results['Trustworthy_Score_A'] = test_ds['Trustworthy_Score']
df_results = df_results[['Image_Name', 'Competency_Score_P', 'Trustworthy_Score_P','Competency_Score_A','Trustworthy_Score_A']]

# %%
df_results.head(5)

# %%
sns.pairplot(df_results)

# %%
#Fold 0

# %%
#Fold 1
mae_comp = np.sum(np.absolute(df_results['Competency_Score_P'] - df_results['Competency_Score_A']))/len(df_results)
mae_trust = np.sum(np.absolute(df_results['Trustworthy_Score_P'] - df_results['Trustworthy_Score_A']))/len(df_results)
print("MAE Competency:", mae_comp)
print("MAE Trustworthy:", mae_trust)
print("MAE Combined:", mae_trust+mae_comp)

# %%
#Fold2
mae_comp = np.sum(np.absolute(df_results['Competency_Score_P'] - df_results['Competency_Score_A']))/len(df_results)
mae_trust = np.sum(np.absolute(df_results['Trustworthy_Score_P'] - df_results['Trustworthy_Score_A']))/len(df_results)
print("MAE Competency:", mae_comp)
print("MAE Trustworthy:", mae_trust)
print("MAE Combined:", mae_trust+mae_comp)

# %%
#Fold3
mae_comp = np.sum(np.absolute(df_results['Competency_Score_P'] - df_results['Competency_Score_A']))/len(df_results)
mae_trust = np.sum(np.absolute(df_results['Trustworthy_Score_P'] - df_results['Trustworthy_Score_A']))/len(df_results)
print("MAE Competency:", mae_comp)
print("MAE Trustworthy:", mae_trust)
print("MAE Combined:", mae_trust+mae_comp)
